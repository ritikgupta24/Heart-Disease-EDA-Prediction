# %%
import pandas as pd
import seaborn as sbn

# %%
import numpy as np

# %%
df = pd.read_csv('/Users/ritik/Downloads/heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
## Checking ages and exploring it (Using Distriution Plot)

# %% [markdown]
# ### Distribution Plot for Numeric Columns

# %%
sbn.distplot(df['Age'], color = 'pink')
# Out:
# /var/folders/mx/g9wlwnds4234knxbrkb__17m0000gn/T/ipykernel_19197/1629030053.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df['Age'], color = 'pink')
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sbn.distplot(df['RestingBP'],kde = True, color = 'red')
# Out:
# /var/folders/mx/g9wlwnds4234knxbrkb__17m0000gn/T/ipykernel_19197/920948285.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df['RestingBP'],kde = True, color = 'red')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sbn.distplot(df['Cholesterol'],kde = True, color = 'yellow')
# Out:
# /var/folders/mx/g9wlwnds4234knxbrkb__17m0000gn/T/ipykernel_19197/2181976009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df['Cholesterol'],kde = True, color = 'yellow')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sbn.distplot(df['MaxHR'],kde = True, color = 'blue')
# Out:
# /var/folders/mx/g9wlwnds4234knxbrkb__17m0000gn/T/ipykernel_19197/1824015455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df['MaxHR'],kde = True, color = 'blue')
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sbn.distplot(df['Oldpeak'],kde = True, color = 'green')
# Out:
# /var/folders/mx/g9wlwnds4234knxbrkb__17m0000gn/T/ipykernel_19197/79471244.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(df['Oldpeak'],kde = True, color = 'green')
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# ### Pie Charts for Categorical

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%.1f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.0f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie' , autopct = '%.0f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.0f') # 1 = True (having heart disease), 2 = False
# Out:
# <Axes: >

# %% [markdown]
# ### Violin Plot (Helps analyze more than 1 thing at a time)

# %%
sbn.violinplot(df['Age'])
# Out:
# <Axes: >

# %%
sns.violinplot(y = df['Sex'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
# Here you can figure out females have lower hear disease compared to men, we just analysed that males have more chances(or positive) of having heart disease as compared to female

# %%
sns.violinplot(y = df['Age'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# ### Correlation - Heatmap

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
#This error occurs because the `corr()` function is trying to calculate correlations between columns, but it encountered a string value ('M') that it can't convert to a float for calculation.

#The error suggests that your DataFrame `df` contains at least one column with string values (like 'M'), which cannot be used in correlation calculations. Correlation can only be computed between numeric columns.

#Would you like me to provide the corrected code?

# %%
df['Sex'] = df['Sex'].map({'M' : 0 , 'F' : 1})

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 df.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40    0           ATA        140          289          0     Normal
# 1     49    1           NAP        160          180          0     Normal
# 2     37    0           ATA        130          283          0         ST
# 3     48    1           ASY        138          214          0     Normal
# 4     54    0           NAP        150          195          0     Normal
# ..   ...  ...           ...        ...          ...        ...        ...
# 913   45    0            TA        110          264          0     Normal
# 914   68    0           ASY        144          193          1     Normal
# 915   57    0           ASY        130          131          0     Normal
# 916   57    1           ATA        130          236          0        LVH
# 917   38    0           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Then create the heatmap with only numeric columns
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >
